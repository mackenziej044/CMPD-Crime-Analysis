# %%
# Import dependencies
import pandas as pd
import os
import numpy as np

# %% [markdown]
# # EXTRACTING CRIME INCIDENT DATA

# %%
# Read the data into a Pandas DataFrame
crime_incident_df = pd.read_csv('Resources/CMPD_Incidents.csv')
crime_incident_df.head(10)
# Out:
# /var/folders/z3/mxhxwwgj7bb1sd23lpfhh6h80000gn/T/ipykernel_93859/1522160804.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime_incident_df = pd.read_csv('Resources/CMPD_Incidents.csv')
#               X              Y  YEAR INCIDENT_REPORT_ID  \
# 0  1.429778e+06  550302.999980  2023   20230817-1203-00
# 1  1.450599e+06  467980.999927  2022   20220206-1938-01
# 2  1.467768e+06  525875.999950  2023   20231218-1423-00
# 3  1.403955e+06  498535.999840  2020   20201011-1424-00
# 4  1.430743e+06  518463.000012  2017   20170401-1213-00
# 5  1.450988e+06  586888.999971  2024   20240113-0129-04
# 6  1.475987e+06  528626.000027  2017   20170802-1513-00
# 7  1.432367e+06  543043.000065  2023   20230114-2030-03
# 8  1.446605e+06  472993.000073  2017   20170829-1949-03
# 9  1.426206e+06  514456.000152  2022   20221012-1737-01
#
#                   LOCATION       CITY STATE      ZIP  X_COORD_PUBLIC  \
# ...

# %%
# Get a brief summary of the crowdfunding_info DataFrame.
crime_incident_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708288 entries, 0 to 708287
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   X                          708288 non-null  float64
#  1   Y                          708288 non-null  float64
#  2   YEAR                       708288 non-null  int64
#  3   INCIDENT_REPORT_ID         708288 non-null  object
#  4   LOCATION                   708288 non-null  object
#  5   CITY                       708288 non-null  object
#  6   STATE                      708273 non-null  object
#  7   ZIP                        477913 non-null  object
#  8   X_COORD_PUBLIC             708288 non-null  int64
#  9   Y_COORD_PUBLIC             708288 non-null  int64
#  10  LATITUDE_PUBLIC            708288 non-null  float64
#  11  LONGITUDE_PUBLIC           708288 non-null  float64
#  12  DIVISION_ID                708288 non-null  object
# ...

# %%
# Access a column by name
column_data = crime_incident_df['CLEARANCE_STATUS']
column_data
# Out:
# 0                          Open
# 1         Exceptionally Cleared
# 2         Exceptionally Cleared
# 3                          Open
# 4         Exceptionally Cleared
#                   ...
# 708283                     Open
# 708284        Cleared by Arrest
# 708285                     Open
# 708286                     Open
# 708287                     Open
# Name: CLEARANCE_STATUS, Length: 708288, dtype: object

# %%
# View unique values
unique_values = crime_incident_df['CLEARANCE_DETAIL_STATUS'].unique()
print(unique_values)
# Out:
# ['Open' 'Located (Missing Persons and Runaways only)'
#  'Cleared by Other Means' 'Victim Chose not to Prosecute'
#  'Cleared by Arrest by Another Agency' 'Unfounded' 'Cleared by Arrest'
#  'Cleared, Pending Arrest Validation' 'Unfounded-Referred to Other Agency'
#  'Prosecution Declined by DA' 'By Death of Offender'
#  'Extradition Declined']

# %%
# Filter rows where 'column_name' is NaN/null
nan_rows = crime_incident_df[crime_incident_df['LONGITUDE_PUBLIC'].isnull()]
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [X, Y, YEAR, INCIDENT_REPORT_ID, LOCATION, CITY, STATE, ZIP, X_COORD_PUBLIC, Y_COORD_PUBLIC, LATITUDE_PUBLIC, LONGITUDE_PUBLIC, DIVISION_ID, CMPD_PATROL_DIVISION, NPA, DATE_REPORTED, DATE_INCIDENT_BEGAN, DATE_INCIDENT_END, ADDRESS_DESCRIPTION, LOCATION_TYPE_DESCRIPTION, PLACE_TYPE_DESCRIPTION, PLACE_DETAIL_DESCRIPTION, CLEARANCE_STATUS, CLEARANCE_DETAIL_STATUS, CLEARANCE_DATE, HIGHEST_NIBRS_CODE, HIGHEST_NIBRS_DESCRIPTION, OBJECTID, GlobalID]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Filter rows where 'column_name' is NaN/null
nan_rows = crime_incident_df[crime_incident_df['LATITUDE_PUBLIC'].isnull()]
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [X, Y, YEAR, INCIDENT_REPORT_ID, LOCATION, CITY, STATE, ZIP, X_COORD_PUBLIC, Y_COORD_PUBLIC, LATITUDE_PUBLIC, LONGITUDE_PUBLIC, DIVISION_ID, CMPD_PATROL_DIVISION, NPA, DATE_REPORTED, DATE_INCIDENT_BEGAN, DATE_INCIDENT_END, ADDRESS_DESCRIPTION, LOCATION_TYPE_DESCRIPTION, PLACE_TYPE_DESCRIPTION, PLACE_DETAIL_DESCRIPTION, CLEARANCE_STATUS, CLEARANCE_DETAIL_STATUS, CLEARANCE_DATE, HIGHEST_NIBRS_CODE, HIGHEST_NIBRS_DESCRIPTION, OBJECTID, GlobalID]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Filter rows where 'column_name' is NaN/null
nan_rows = crime_incident_df[crime_incident_df['CLEARANCE_DATE'].isnull()]
print(nan_rows)
# Out:
#                    X              Y  YEAR INCIDENT_REPORT_ID  \
# 0       1.429778e+06  550302.999980  2023   20230817-1203-00
# 3       1.403955e+06  498535.999840  2020   20201011-1424-00
# 13      1.458438e+06  540084.000077  2024   20240204-1816-00
# 14      1.464922e+06  571452.000005  2017   20171027-1156-00
# 15      1.453926e+06  503112.999872  2019   20191216-1612-01
# ...              ...            ...   ...                ...
# 708279  1.482246e+06  527710.999889  2024   20240114-1158-01
# 708283  1.408708e+06  520959.999939  2017   20170508-0839-02
# 708285  1.449626e+06  542725.000045  2023   20230806-1240-02
# 708286  1.432479e+06  551277.000001  2022   20220711-2140-00
# 708287  1.476961e+06  523536.000037  2018   20180406-0123-00
#
#                        LOCATION       CITY STATE      ZIP  X_COORD_PUBLIC  \
# 0           3100 TIMBERBROOK DR  CHARLOTTE    NC  28208.0         1429778
# 3       10000 CLOISTERS CLUB LN  CHARLOTTE    NC  28278.0         1403955
# ...

# %%
crime_incident_df['CLEARANCE_DATE']
# Out:
# 0                            NaN
# 1         2022/02/08 00:00:00+00
# 2         2024/02/08 00:00:00+00
# 3                            NaN
# 4         2019/07/30 00:00:00+00
#                    ...
# 708283                       NaN
# 708284    2017/08/06 00:00:00+00
# 708285                       NaN
# 708286                       NaN
# 708287                       NaN
# Name: CLEARANCE_DATE, Length: 708288, dtype: object

# %%
crime_incident_df['HIGHEST_NIBRS_DESCRIPTION']
# Out:
# 0                                           Suicide
# 1                                    Missing Person
# 2                       Other Unlisted Non-Criminal
# 3         Theft of Motor Vehicle Parts from Vehicle
# 4                                      Intimidation
#                             ...
# 708283                 Damage/Vandalism Of Property
# 708284                           All Other Offenses
# 708285                                  Shoplifting
# 708286                               Simple Assault
# 708287                                 Burglary/B&E
# Name: HIGHEST_NIBRS_DESCRIPTION, Length: 708288, dtype: object

# %%
unique_values = crime_incident_df['HIGHEST_NIBRS_DESCRIPTION'].unique()
print(unique_values)
# Out:
# ['Suicide' 'Missing Person' 'Other Unlisted Non-Criminal'
#  'Theft of Motor Vehicle Parts from Vehicle' 'Intimidation'
#  'Aggravated Assault' 'Theft From Motor Vehicle'
#  'Trespass Of Real Property' 'Overdose' 'Drug/Narcotic Violations'
#  'Impersonation' 'Burglary/B&E' 'False Pretenses/Swindle'
#  'Stolen Property Offenses' 'Drug Equipment Violations' 'All Other Thefts'
#  'Shoplifting' 'Damage/Vandalism Of Property' 'Motor Vehicle Theft'
#  'Simple Assault' 'Identity Theft' 'Theft From Building'
#  'All Other Offenses' 'Forcible Rape' 'Pornography/Obscene Material'
#  'Sudden/Natural Death Investigation' 'Credit Card/Teller Fraud'
#  'Forcible Fondling' 'Weapon Law Violations' 'Disorderly Conduct'
#  'Indecent Exposure' 'Affray' 'Robbery' 'Driving Under The Influence'
#  'Kidnapping' 'Vehicle Recovery' 'Pocket-Picking' 'Liquor Law Violations'
#  'Embezzlement' 'Public Accident' 'Counterfeiting/Forgery'
#  'Hacking/Computer Invasion' 'Arson' 'Murder' 'Statutory Rape'
# ...
