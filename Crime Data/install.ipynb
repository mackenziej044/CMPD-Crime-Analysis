# %%
from flask import Flask, jsonify
import pandas as pd 
import sqlite3

# %%
app = Flask(__name__)

# %%
conn = sqlite3.connect('cmpd_data.db') 

crime_df = pd.read_sql_query("SELECT * FROM cmpd_data", conn)  # Read data into a DataFrame

conn.close()  # Close the connection

crime_df.head()
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID  \
# 0  1.429778e+06  550302.999980  2023   20230817-1203-00
# 1  1.450599e+06  467980.999927  2022   20220206-1938-01
# 2  1.467768e+06  525875.999950  2023   20231218-1423-00
# 3  1.403955e+06  498535.999840  2020   20201011-1424-00
# 4  1.430743e+06  518463.000012  2017   20170401-1213-00
#
#                   LOCATION       CITY STATE    ZIP  X_COORD_PUBLIC  \
# 0      3100 TIMBERBROOK DR  CHARLOTTE    NC  28208         1429778
# 1       10900 SEDGEMOOR LN  CHARLOTTE    NC   None         1450599
# 2        4300 CASTLETON RD  CHARLOTTE    NC  28211         1467768
# 3  10000 CLOISTERS CLUB LN  CHARLOTTE    NC  28278         1403955
# 4          700 DUNBROOK LN  CHARLOTTE    NC  28217         1430743
#
#    Y_COORD_PUBLIC  ...  LOCATION_TYPE_DESCRIPTION  PLACE_TYPE_DESCRIPTION  \
# 0          550303  ...                    Indoors             Residential
# ...

# %%
@app.route('/data', methods=['GET'])
def get_data():
    crime_df = fetch_data()  # Fetch data from the database
    data = crime_df.to_dict(orient='records')  # Convert DataFrame to a list of dictionaries
    return jsonify(data)  # Return the data as JSON
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 @app.route('/data', methods=['GET'])
#       2 def get_data():
#       3     crime_df = fetch_data()  # Fetch data from the database
#       4     data = crime_df.to_dict(orient='records')  # Convert DataFrame to a list of dictionaries
#
# File /Applications/anaconda3/lib/python3.12/site-packages/flask/sansio/scaffold.py:362, in Scaffold.route.<locals>.decorator(f)
#     360 def decorator(f: T_route) -> T_route:
#     361     endpoint = options.pop("endpoint", None)
# --> 362     self.add_url_rule(rule, endpoint, f, **options)
#     363     return f
#
# File /Applications/anaconda3/lib/python3.12/site-packages/flask/sansio/scaffold.py:47, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      45 def wrapper_func(self: Scaffold, *args: t.Any, **kwargs: t.Any) -> t.Any:
# ...

# %%
# Run server
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (fsevents)
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Applications/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
# ...
