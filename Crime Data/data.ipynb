# %%
import sqlite3

conn = sqlite3.connect('cmpd_data.db')
c = conn.cursor()

# %%
import pandas as pd

# load the data into a Pandas DataFrame
cmpd_data = pd.read_csv('CMPD_Incidents.csv', low_memory=False)
# write the data to a sqlite table
cmpd_data.to_sql('cmpd_data', conn, if_exists='append', index = False)
# Out:
# 708288

# %%
cmpd_data.head()
# Out:
#               X              Y  YEAR INCIDENT_REPORT_ID  \
# 0  1.429778e+06  550302.999980  2023   20230817-1203-00
# 1  1.450599e+06  467980.999927  2022   20220206-1938-01
# 2  1.467768e+06  525875.999950  2023   20231218-1423-00
# 3  1.403955e+06  498535.999840  2020   20201011-1424-00
# 4  1.430743e+06  518463.000012  2017   20170401-1213-00
#
#                   LOCATION       CITY STATE    ZIP  X_COORD_PUBLIC  \
# 0      3100 TIMBERBROOK DR  CHARLOTTE    NC  28208         1429778
# 1       10900 SEDGEMOOR LN  CHARLOTTE    NC    NaN         1450599
# 2        4300 CASTLETON RD  CHARLOTTE    NC  28211         1467768
# 3  10000 CLOISTERS CLUB LN  CHARLOTTE    NC  28278         1403955
# 4          700 DUNBROOK LN  CHARLOTTE    NC  28217         1430743
#
#    Y_COORD_PUBLIC  ...  LOCATION_TYPE_DESCRIPTION  PLACE_TYPE_DESCRIPTION  \
# 0          550303  ...                    Indoors             Residential
# ...
